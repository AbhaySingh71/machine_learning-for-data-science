# %% [markdown]
# \# Assignment
#
# **Name:** Abhay
# **ID:** 08117702023
# **Class:** BCA V-B
# **Assistant Professor:** Mamta Madan
#
# ---
#
# ## Questions based on Naive Bayes
#
# **Instructor:** Mamta Madan
# **Points:** 100
# **Due Date:12 september**
#
# ---

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score

# %%
# Synthetic dataset: symptoms vs disease
data = {
    "Cough": ["Yes","Yes","No","Yes","No","Yes","No","Yes","No","No"],
    "SoreThroat": ["Yes","No","No","Yes","Yes","No","Yes","No","Yes","No"],
    "Temperature": ["High","High","Normal","High","Normal","High","Normal","Normal","High","Normal"],
    "Headache": ["Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No"],
    "Disease": ["COVID","COVID","Fever","Flu","Fever","COVID","Flu","Fever","Flu","Fever"]
}

# %%
df = pd.DataFrame(data)

# %%
# Encode categorical features numerically
for col in df.columns:
    df[col] = df[col].astype('category').cat.codes

# %%
X = df.drop(columns=['Disease'])
y = df['Disease']

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
nb = CategoricalNB()
nb.fit(X_train, y_train)
# Out:
# CategoricalNB()

# %%
# Predictions
y_pred = nb.predict(X_test)

# %%
# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
#accuracy, list(zip(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred, labels=nb.classes_)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=nb.classes_, yticklabels=nb.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Naïve Bayes - Confusion Matrix")
plt.show()
